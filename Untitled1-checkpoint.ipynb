# %%
from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')

slices=[20,30,40,10]

labels=['twenty','thirty','fourty','ten']

plt.pie(slices, labels=labels)

plt.title('show my pie chart')

plt.tight_layout()

plt.show()
